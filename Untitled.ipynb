# %%
pip install opencv-python

# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv("malicious_url.csv")
df.head()
# Out:
#    Unnamed: 0                                                url        type  \
# 0           0                                   br-icloud.com.br    phishing
# 1           1                mp3raid.com/music/krizz_kaliko.html      benign
# 2           2                    bopsecrets.org/rexroth/cr/1.htm      benign
# 3           3  http://www.garage-pirenne.be/index.php?option=...  defacement
# 4           4  http://adventure-nicaragua.net/index.php?optio...  defacement
#
#    url_length
# 0          16
# 1          35
# 2          31
# 3          88
# 4         235

# %%
lst=df["url"]

# %%
x=0
chars=[]
res = []
for ele in lst:
    chars=[]
    for num in ele:
        chars.append(ord(num))
    res.append(chars)

# %%
res
# Out:
# [[98, 114, 45, 105, 99, 108, 111, 117, 100, 46, 99, 111, 109, 46, 98, 114],
#  [109,
#   112,
#   51,
#   114,
#   97,
#   105,
#   100,
#   46,
#   99,
#   111,
#   109,
#   47,
#   109,
#   117,
#   115,
#   105,
#   99,
#   47,
#   107,
#   114,
#   105,
#   122,
#   122,
#   95,
#   107,
#   97,
#   108,
#   105,
#   107,
#   111,
#   46,
#   104,
#   116,
#   109,
#   108],
#  [98,
#   111,
#   112,
#   115,
#   101,
#   99,
#   114,
#   101,
#   116,
#   115,
#   46,
#   111,
#   114,
#   103,
#   47,
#   114,
#   101,
#   120,
#   114,
#   111,
#   116,
#   104,
#   47,
#   99,
#   114,
#   47,
#   49,
#   46,
#   104,
#   116,
#   109],
#  [104,
#   116,
#   116,
#   112,
#   58,
#   47,
#   47,
#   119,
#   119,
#   119,
#   46,
#   103,
#   97,
#   114,
#   97,
#   103,
#   101,
#   45,
#   112,
#   105,
#   114,
#   101,
#   110,
#   110,
#   101,
#   46,
#   98,
#   101,
#   47,
#   105,
#   110,
#   100,
#   101,
#   120,
#   46,
#   112,
#   104,
#   112,
#   63,
# ...
