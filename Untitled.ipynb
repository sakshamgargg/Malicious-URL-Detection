# %%
import pandas as pd
import numpy as np

# %%
dataset=pd.read_csv("malicious_url.csv")

# %%
dataset['Uppercase'] = dataset['url'].str.count(r'[A-Z]')
dataset['Lowercase'] = dataset['url'].str.count(r'[a-z]')

# %%
dataset.head()
# Out:
#    Unnamed: 0                                                url        type  \
# 0           0                                   br-icloud.com.br    phishing
# 1           1                mp3raid.com/music/krizz_kaliko.html      benign
# 2           2                    bopsecrets.org/rexroth/cr/1.htm      benign
# 3           3  http://www.garage-pirenne.be/index.php?option=...  defacement
# 4           4  http://adventure-nicaragua.net/index.php?optio...  defacement
#
#    url_length  Uppercase  Lowercase
# 0          16          0         13
# 1          35          0         29
# 2          31          0         25
# 3          88          0         63
# 4         235         63        136

# %%
dataset.reset_index(drop=True)
# Out:
#         Unnamed: 0                                                url  \
# 0                0                                   br-icloud.com.br
# 1                1                mp3raid.com/music/krizz_kaliko.html
# 2                2                    bopsecrets.org/rexroth/cr/1.htm
# 3                3  http://www.garage-pirenne.be/index.php?option=...
# 4                4  http://adventure-nicaragua.net/index.php?optio...
# ...            ...                                                ...
# 651186      651186            xbox360.ign.com/objects/850/850402.html
# 651187      651187       games.teamxbox.com/xbox-360/1860/Dead-Space/
# 651188      651188         www.gamespot.com/xbox360/action/deadspace/
# 651189      651189      en.wikipedia.org/wiki/Dead_Space_(video_game)
# 651190      651190          www.angelfire.com/goth/devilmaycrytonite/
#
#               type  url_length  Uppercase  Lowercase
# 0         phishing          16          0         13
# 1           benign          35          0         29
# 2           benign          31          0         25
# 3       defacement          88          0         63
# 4       defacement         235         63        136
# ...            ...         ...        ...        ...
# 651186    phishing          39          0         21
# 651187    phishing          44          2         27
# 651188    phishing          42          0         33
# 651189    phishing          45          2         34
# 651190    phishing          41          0         36
#
# [651191 rows x 6 columns]

# %%
dataset['Ratio of Ucase to Lcase'] = dataset['Uppercase'] / dataset['Lowercase']

# %%
dataset.head()
# Out:
#    Unnamed: 0                                                url        type  \
# 0           0                                   br-icloud.com.br    phishing
# 1           1                mp3raid.com/music/krizz_kaliko.html      benign
# 2           2                    bopsecrets.org/rexroth/cr/1.htm      benign
# 3           3  http://www.garage-pirenne.be/index.php?option=...  defacement
# 4           4  http://adventure-nicaragua.net/index.php?optio...  defacement
#
#    url_length  Uppercase  Lowercase  Ratio of Ucase to Lcase
# 0          16          0         13                 0.000000
# 1          35          0         29                 0.000000
# 2          31          0         25                 0.000000
# 3          88          0         63                 0.000000
# 4         235         63        136                 0.463235
